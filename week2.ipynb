# %% [markdown]
# 特征提取的原理：minimize the variation in our features and our scripted that's caused by things that are irrelevant to expression such as lighting or identity。we want to maxmize the variation or features that are relevant to facial expression and in our case that is quite edges so we want to sort of encode edges in a very cheap way and a very interesting and very successful feature for that is called the local binary pattern. [1]
#
# space was based purely on pixel intensities into a low dimensional space that only encodes relative intensity values and in doing so encodes edges so we now have got an illumination invariant descriptor of edges when you think about it
#
# facial expression recognition is actualy action detection
#
# 我们想检测的不是一个静态的微笑，而是一个变化的表情，要发现的是不同，因此需要关注的是这些像素如果随着时间的变化而变化，因此加入时间的坐标后，二维矩阵扩展成三维矩阵
#
# ![image.png](attachment:image.png)

# %% [markdown]
# OpenCV中使用了LBP算法，但是没有提供函数接口。
#
# ![image.png](attachment:image.png)
#
# 理特征定义为邻域像素和中心像素的差的联合分布函数。
# 统计量T 是一个跟亮度均值，即灰度级无关的值
#
# 计算LBP特征的图像必须是灰度图，如果是彩色图，需要先转换成灰度图
#
#
# 基本的 LBP算子的最大缺陷在于它只覆盖了一个固定半径范围内的小区域
#
#
# 一般都不将LBP图谱作为特征向量用于分类识别，而是采用LBP特征谱的统计直方图作为特征向量用于分类识别。

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 第一步、将检测窗口划分为16×16的小区域（cell）
# 第一步、计算某局部区域中心像素点的LBP，通常将8位二进制数转换为十进制数即LBP码，共256种
# （3）然后计算每个cell的直方图，即每个数字（假定是十进制数LBP值）出现的频率；然后对该直方图进行归一化处理。
# （4）最后将得到的每个cell的统计直方图进行连接成为一个特征向量，也就是整幅图的LBP纹理特征向量；

# %% [markdown]
# LBP作用：纹理特征提取，以某局部区域中心像素点的LTP值来反映该区域的纹理信息。
#
# LBP特性：旋转不变形、
#
# 灰度不变性：当有一束光打在图像上，所有像素都会改变，但是像素之间的差别不会改变

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 这些transition是edges

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 参考资料：
# [1]https://www.youtube.com/watch?v=wpAwdsubl1w
